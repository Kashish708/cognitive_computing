# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Part I
roll_number = 102317186
np.random.seed(roll_number)


sales_data = np.random.randint(1000, 5001, size=(12, 4))
categories = ["Electronics", "Clothing", "Home & Kitchen", "Sports"]
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]


df = pd.DataFrame(sales_data, columns=categories, index=months)
print(df.head())
print(df.describe())
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         1835      1185            3683    2126
# Feb         1712      2284            4931    3148
# Mar         1503      1508            3878    4948
# Apr         1355      1901            2680    1834
# May         2218      2390            1388    3151
#        Electronics     Clothing  Home & Kitchen       Sports
# count    12.000000    12.000000       12.000000    12.000000
# mean   2572.916667  2920.416667     2922.083333  3368.416667
# std    1356.569233  1178.309996     1475.676514  1107.605563
# min    1215.000000  1185.000000     1026.000000  1834.000000
# 25%    1659.750000  1916.000000     1411.250000  2336.250000
# 50%    1845.500000  2782.000000     3181.500000  3149.500000
# 75%    4018.500000  4121.500000     4114.750000  4223.000000
# max    4557.000000  4349.000000     4931.000000  4948.000000

# %%
# Part II
total_sales_per_category = df.sum()
print("Total Sales per Category:\n", total_sales_per_category)


df["Total Sales"] = df.sum(axis=1)


df["Growth Rate"] = df["Total Sales"].pct_change() * 100


if roll_number % 2 == 0:
    df["Electronics"] *= 0.9
else:
    df["Clothing"] *= 0.85

print(df.head())
# Out:
# Total Sales per Category:
#  Electronics       30875
# Clothing          35045
# Home & Kitchen    35065
# Sports            40421
# dtype: int64
#      Electronics  Clothing  Home & Kitchen  Sports  Total Sales  Growth Rate
# Jan       1651.5      1185            3683    2126         8829          NaN
# Feb       1540.8      2284            4931    3148        12075    36.765206
# Mar       1352.7      1508            3878    4948        11837    -1.971014
# Apr       1219.5      1901            2680    1834         7770   -34.358368
# May       1996.2      2390            1388    3151         9147    17.722008

# %%
# Part III
plt.figure(figsize=(10, 5))
for category in categories:
    plt.plot(df.index, df[category], marker='o', label=category)
plt.legend()
plt.title("Monthly Sales Trends")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.show()


plt.figure(figsize=(8, 5))
sns.boxplot(data=df[categories])
plt.title("Sales Distribution Per Category")
plt.show()

# %%
# Q.2
array = np.array([[1, -2, 3], [-4, 5, -6]])
print("Element-wise Absolute Value:\n", np.abs(array))
print("Percentiles:")
print("25th:", np.percentile(array, 25, axis=None))
print("50th:", np.percentile(array, 50, axis=None))
print("75th:", np.percentile(array, 75, axis=None))
print("Mean:", np.mean(array))
print("Median:", np.median(array))
print("Std Dev:", np.std(array))
# Out:
# Element-wise Absolute Value:
#  [[1 2 3]
#  [4 5 6]]
# Percentiles:
# 25th: -3.5
# 50th: -0.5
# 75th: 2.5
# Mean: -0.5
# Median: -0.5
# Std Dev: 3.8622100754188224

# %%
# Q.3
a = np.array([-1.8, -1.6, -0.5, 0.5, 1.6, 1.8, 3.0])
print("Floor:", np.floor(a))
print("Ceiling:", np.ceil(a))
print("Truncate:", np.trunc(a))
print("Rounded:", np.round(a))
# Out:
# Floor: [-2. -2. -1.  0.  1.  1.  3.]
# Ceiling: [-1. -1. -0.  1.  2.  2.  3.]
# Truncate: [-1. -1. -0.  0.  1.  1.  3.]
# Rounded: [-2. -2. -0.  0.  2.  2.  3.]

# %%
# Q.4
lst = [1, 2, 3, 4, 5]
temp = lst[1]
lst[1] = lst[3]
lst[3] = temp
print("Swapped List:", lst)
# Out:
# Swapped List: [1, 4, 3, 2, 5]

# %%
# Q.5
s = {10, 20, 30, 40, 50}
s_list = list(s)
s_list[0], s_list[2] = s_list[2], s_list[0]
s = set(s_list)
print("Swapped Set:", s)
# Out:
# Swapped Set: {40, 10, 50, 20, 30}
